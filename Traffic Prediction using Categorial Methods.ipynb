# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Reading the dataset 
df = pd.read_csv('Traffic.csv')
df
# Out:
#              Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0     12:00:00 AM    10         Tuesday        31          0         4
# 1     12:15:00 AM    10         Tuesday        49          0         3
# 2     12:30:00 AM    10         Tuesday        46          0         3
# 3     12:45:00 AM    10         Tuesday        51          0         2
# 4      1:00:00 AM    10         Tuesday        57          6        15
# ...           ...   ...             ...       ...        ...       ...
# 2971  10:45:00 PM     9        Thursday        16          3         1
# 2972  11:00:00 PM     9        Thursday        11          0         1
# 2973  11:15:00 PM     9        Thursday        15          4         1
# 2974  11:30:00 PM     9        Thursday        16          5         0
# 2975  11:45:00 PM     9        Thursday        14          3         1
#
#       TruckCount  Total Traffic Situation
# 0              4     39               low
# 1              3     55               low
# 2              6     55               low
# 3              5     58               low
# 4             16     94            normal
# ...          ...    ...               ...
# 2971          36     56            normal
# 2972          30     42            normal
# 2973          25     45            normal
# 2974          27     48            normal
# 2975          15     33            normal
#
# [2976 rows x 9 columns]

# %% [markdown]
# # Gathering the Basic Information

# %%
#Shape of the Dataset i.e number of rows and columns
shape = df.shape
print("Shape = ",shape)
# Out:
# Shape =  (2976, 9)

# %%
#Information of each column
print("-Information of each column-")
info = df.info()
print(info)
# Out:
# -Information of each column-
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2976 entries, 0 to 2975
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Time               2976 non-null   object
#  1   Date               2976 non-null   int64
#  2   Day of the week    2976 non-null   object
#  3   CarCount           2976 non-null   int64
#  4   BikeCount          2976 non-null   int64
#  5   BusCount           2976 non-null   int64
#  6   TruckCount         2976 non-null   int64
#  7   Total              2976 non-null   int64
#  8   Traffic Situation  2976 non-null   object
# dtypes: int64(6), object(3)
# memory usage: 209.4+ KB
# None

# %%
#Count of the rows in each column
print("-Count of the rows in each column-")
count = df.count()
print(count)
# Out:
# -Count of the rows in each column-
# Time                 2976
# Date                 2976
# Day of the week      2976
# CarCount             2976
# BikeCount            2976
# BusCount             2976
# TruckCount           2976
# Total                2976
# Traffic Situation    2976
# dtype: int64

# %%
#Minimum value from each column
print("-Minimum value from each column-")
min = df.min()
print(min)
# Out:
# -Minimum value from each column-
# Time                 10:00:00 AM
# Date                           1
# Day of the week           Friday
# CarCount                       6
# BikeCount                      0
# BusCount                       0
# TruckCount                     0
# Total                         21
# Traffic Situation          heavy
# dtype: object

# %%
#Maximum value from each column
print("  -Maximum value from each column-  ")
max = df.max()
print(max)
# Out:
#   -Maximum value from each column-
# Time                 9:45:00 PM
# Date                         31
# Day of the week       Wednesday
# CarCount                    180
# BikeCount                    70
# BusCount                     50
# TruckCount                   40
# Total                       279
# Traffic Situation        normal
# dtype: object

# %%
#Measure of Central Tendany
print("-Measure of Central Tendency and Five Point Summary-")
df.describe()
# Out:
# -Measure of Central Tendency and Five Point Summary-
#               Date     CarCount    BikeCount     BusCount   TruckCount  \
# count  2976.000000  2976.000000  2976.000000  2976.000000  2976.000000
# mean     16.000000    68.696573    14.917339    15.279570    15.324933
# std       8.945775    45.850693    12.847518    14.341986    10.603833
# min       1.000000     6.000000     0.000000     0.000000     0.000000
# 25%       8.000000    19.000000     5.000000     1.000000     6.000000
# 50%      16.000000    64.000000    12.000000    12.000000    14.000000
# 75%      24.000000   107.000000    22.000000    25.000000    23.000000
# max      31.000000   180.000000    70.000000    50.000000    40.000000
#
#              Total
# count  2976.000000
# mean    114.218414
# std      60.190627
# min      21.000000
# 25%      55.000000
# 50%     109.000000
# 75%     164.000000
# max     279.000000

# %%
#Top 5 rows of dataset
print("Top 5 rows of dataset")
df.head()
# Out:
# Top 5 rows of dataset
#           Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0  12:00:00 AM    10         Tuesday        31          0         4
# 1  12:15:00 AM    10         Tuesday        49          0         3
# 2  12:30:00 AM    10         Tuesday        46          0         3
# 3  12:45:00 AM    10         Tuesday        51          0         2
# 4   1:00:00 AM    10         Tuesday        57          6        15
#
#    TruckCount  Total Traffic Situation
# 0           4     39               low
# 1           3     55               low
# 2           6     55               low
# 3           5     58               low
# 4          16     94            normal

# %%
#Bottom 5 rows of dataset
print("Bottom 5 rows of dataset")
df.tail()
# Out:
# Bottom 5 rows of dataset
#              Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 2971  10:45:00 PM     9        Thursday        16          3         1
# 2972  11:00:00 PM     9        Thursday        11          0         1
# 2973  11:15:00 PM     9        Thursday        15          4         1
# 2974  11:30:00 PM     9        Thursday        16          5         0
# 2975  11:45:00 PM     9        Thursday        14          3         1
#
#       TruckCount  Total Traffic Situation
# 2971          36     56            normal
# 2972          30     42            normal
# 2973          25     45            normal
# 2974          27     48            normal
# 2975          15     33            normal

# %%
#Check the null values
print("Null Values")
df.isnull().sum()
# Out:
# Null Values
# Time                 0
# Date                 0
# Day of the week      0
# CarCount             0
# BikeCount            0
# BusCount             0
# TruckCount           0
# Total                0
# Traffic Situation    0
# dtype: int64

# %%
df.drop(columns = ['Time','Day of the week'],inplace = True)

# %%
#Check the Duplicate values
print("Duplicate Values")
df.duplicated().sum()
# Out:
# Duplicate Values
# 5

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Traffic Situation'].unique()
# Out:
# array(['low', 'normal', 'heavy', 'high'], dtype=object)

# %%
df['Traffic Situation']=df['Traffic Situation'].map({'low':0, 'normal':1,'heavy':2,'high':3})
df
# Out:
#       Date  CarCount  BikeCount  BusCount  TruckCount  Total  \
# 0       10        31          0         4           4     39
# 1       10        49          0         3           3     55
# 2       10        46          0         3           6     55
# 3       10        51          0         2           5     58
# 4       10        57          6        15          16     94
# ...    ...       ...        ...       ...         ...    ...
# 2971     9        16          3         1          36     56
# 2972     9        11          0         1          30     42
# 2973     9        15          4         1          25     45
# 2974     9        16          5         0          27     48
# 2975     9        14          3         1          15     33
#
#       Traffic Situation
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     1
# ...                 ...
# 2971                  1
# 2972                  1
# 2973                  1
# 2974                  1
# 2975                  1
#
# [2971 rows x 7 columns]

# %% [markdown]
# # Identification of outliers using boxplot and IQR

# %%
box = sns.boxplot(df)
box.set_title('BoxPlot for each column')
plt.show()

# %%
#Box plot for each column 
fig, axes = plt.subplots(3, 2, figsize=(12, 10))

sns.boxplot(data=df, x='Date', palette = 'Blues',ax=axes[0, 0])
axes[0, 0].set_title('Box Plot for Date')

sns.boxplot(data=df, x='CarCount',palette ='husl', ax=axes[0, 1])
axes[0, 1].set_title('Box Plot for CarCount')

sns.boxplot(data=df, x='BikeCount',palette ='deep', ax=axes[1, 0])
axes[1, 0].set_title('Box Plot for BikeCount')

sns.boxplot(data=df, x='BusCount',palette ='viridis', ax=axes[1, 1])
axes[1, 1].set_title('Box Plot for BusCount')

sns.boxplot(data=df, x='TruckCount',palette ='deep', ax=axes[2, 0])
axes[2, 0].set_title('Box Plot for BikeCount')

sns.boxplot(data=df, x='Total',palette ='viridis', ax=axes[2, 1])
axes[2, 1].set_title('Box Plot for Total')
plt.tight_layout()
plt.show()

# %%
Q1 = df['BikeCount'].quantile(0.25)
Q3 = df['BikeCount'].quantile(0.75)
IQR = Q3-Q1
threshold=1.5 
admit_outliers=df[(df['BikeCount'] <Q1-threshold*IQR) | (df['BikeCount'] > Q3+ threshold*IQR)]
admit_outliers
# Out:
#       Date  CarCount  BikeCount  BusCount  TruckCount  Total  \
# 326     13       131         52        15           0    198
# 327     13       171         59        27           3    260
# 329     13       177         56        12           4    249
# 331     13       178         68        28           4    278
# 332     13       169         70        20           3    262
# ...    ...       ...        ...       ...         ...    ...
# 2359     3       142         55        21           1    219
# 2360     3       144         59        14           2    219
# 2361     3       180         49        17           0    246
# 2362     3       153         59        20           4    236
# 2364     3       179         60        12           0    251
#
#       Traffic Situation
# 326                   2
# 327                   2
# 329                   2
# 331                   2
# 332                   2
# ...                 ...
# 2359                  2
# 2360                  2
# 2361                  2
# 2362                  2
# 2364                  2
#
# [77 rows x 7 columns]

# %%
df=df.drop(admit_outliers.index)
sns.boxplot(x='BikeCount',data=df)
# Out:
# <Axes: xlabel='BikeCount'>

# %% [markdown]
# # Dataset Trend Visualization

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

sns.lineplot(data=df, x='Traffic Situation' ,y='Date',color ='g',ax=axes[0])
axes[0].set_title('Line Plot for Date vs Traffic Situation')

sns.lineplot(data=df, x='Traffic Situation',y='TruckCount', ax=axes[1])
axes[1].set_title('Line Plot for Truck Count vs Traffic Situation')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

sns.lineplot(data=df, x='Traffic Situation' ,y='CarCount',color ='g',ax=axes[0])
axes[0].set_title('Line Plot for Car count vs Traffic Situation')

sns.lineplot(data=df, x='Traffic Situation',y='BikeCount', ax=axes[1])
axes[1].set_title('Line Plot for Bike Count vs Traffic Situation')

plt.tight_layout()
plt.show()

# %%
df.hist(figsize = (15,8))
# Out:
# array([[<Axes: title={'center': 'Date'}>,
#         <Axes: title={'center': 'CarCount'}>,
#         <Axes: title={'center': 'BikeCount'}>],
#        [<Axes: title={'center': 'BusCount'}>,
#         <Axes: title={'center': 'TruckCount'}>,
#         <Axes: title={'center': 'Total'}>],
#        [<Axes: title={'center': 'Traffic Situation'}>, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
v = df['Traffic Situation'].value_counts().values
labels = ['low', 'normal', 'high', 'heavy']
explode = [0.2,0,0,0]
#pie chart
import matplotlib.pyplot as plt
plt.figure(figsize = (6,6))
plt.pie(x=v,labels=labels,explode=explode,autopct = '%0.1f%%')
plt.show()

# %%
#Pairplot for entire data
sns.pairplot(df)
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Heatmap for Correlation Data 
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Test and Train Splitting

# %%
# splitting the data into x and y
x=df.iloc[:,0:6]
y=df.iloc[:,-1]
x
# Out:
#       Date  CarCount  BikeCount  BusCount  TruckCount  Total
# 0       10        31          0         4           4     39
# 1       10        49          0         3           3     55
# 2       10        46          0         3           6     55
# 3       10        51          0         2           5     58
# 4       10        57          6        15          16     94
# ...    ...       ...        ...       ...         ...    ...
# 2971     9        16          3         1          36     56
# 2972     9        11          0         1          30     42
# 2973     9        15          4         1          25     45
# 2974     9        16          5         0          27     48
# 2975     9        14          3         1          15     33
#
# [2894 rows x 6 columns]

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 2971    1
# 2972    1
# 2973    1
# 2974    1
# 2975    1
# Name: Traffic Situation, Length: 2894, dtype: int64

# %%
# Splitting the x and y into train and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=42)
x_train
# Out:
#       Date  CarCount  BikeCount  BusCount  TruckCount  Total
# 909     19        49          5        10          21     85
# 1655    27        77         20         4          13    114
# 1905    29        60         23        11          26    120
# 2771     7        89          7        10          10    116
# 217     12       114         32        34           2    182
# ...    ...       ...        ...       ...         ...    ...
# 1699    27        82         20        15           2    119
# 1136    21        96         15        12          27    150
# 1171    22       102         20         9          13    144
# 1335    23       106          9        12          31    158
# 881     19       115         16        10          13    154
#
# [1736 rows x 6 columns]

# %%
#Transforming the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() #removes the mean and scales each feature/variable to unit variance.
x_train = scaler.fit_transform(x_train) 
x_test = scaler.transform(x_test)
x_test
# Out:
# array([[ 1.56142254, -0.74741744, -0.75319531, -0.59665199,  0.89046297,
#         -0.70297399],
#        [ 0.56151821, -0.20579817, -0.4729466 ,  0.62881017, -0.24542121,
#         -0.13072569],
#        [-1.21608948, -0.02525841, -0.00586542,  0.35648525, -0.81336331,
#         -0.07870312],
#        ...,
#        [-1.104989  ,  1.59959942,  0.46121576,  1.37770371, -1.00267734,
#          1.48197405],
#        [ 0.00601581,  1.12568256, -0.28611413,  1.99043479, -1.47596242,
#          1.04845261],
#        [ 1.11702062,  0.56149581, -0.94002778, -0.66473322,  0.22786386,
#          0.12938717]])

# %% [markdown]
# # Logistic Regressor

# %%
#Importing the LogesticRegression library
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression()

# %%
# Assigning the Parameters
from sklearn.model_selection import GridSearchCV
parameter ={'penalty':['l1','l2','elasticnet'],
             'C':[1,2,3,4,5,6,10,20,30,40,50],
              'max_iter':[100,200,300]}

classifier_regressor = GridSearchCV(classifier,
                                    param_grid = parameter,
                                    scoring='accuracy',
                                    cv = 5)

classifier_regressor.fit(x_train, y_train)
print(classifier_regressor.best_score_)
# Out:
# 0.8991950710523702
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 330 fits failed out of a total of 495.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 165 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1168, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 165 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1168, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [       nan 0.89919507        nan        nan 0.89919507        nan
#         nan 0.89919507        nan        nan 0.89631654        nan
#         nan 0.89631654        nan        nan 0.89631654        nan
#         nan 0.89573851        nan        nan 0.89573851        nan
#         nan 0.89573851        nan        nan 0.89631323        nan
#         nan 0.89631323        nan        nan 0.89631323        nan
#         nan 0.89631323        nan        nan 0.89631323        nan
#         nan 0.89631323        nan        nan 0.89746431        nan
#         nan 0.89746431        nan        nan 0.89746431        nan
#         nan 0.89688794        nan        nan 0.89688794        nan
#         nan 0.89688794        nan        nan 0.89516215        nan
#         nan 0.89516215        nan        nan 0.89516215        nan
#         nan 0.89573851        nan        nan 0.89573851        nan
#         nan 0.89573851        nan        nan 0.89573851        nan
#         nan 0.89573851        nan        nan 0.89573851        nan
#         nan 0.89573851        nan        nan 0.89573851        nan
#         nan 0.89573851        nan]
#   warnings.warn(

# %%
#Predicting x_test
classifier_regressor.predict(x_test)
# Out:
# array([1, 1, 1, ..., 2, 2, 1], dtype=int64)

# %%
# assigning the y_pred 
y_pred = classifier_regressor.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, ..., 2, 2, 1], dtype=int64)

# %%
# Calculating the accuracy
from sklearn.metrics import accuracy_score,classification_report
score_lr = accuracy_score(y_pred,y_test)
print("Accuracy:",score_lr*100,"%")
# Out:
# Accuracy: 88.6873920552677 %

# %%
#Predicting the result
lr = classifier_regressor.predict([[10,31,0,4,4,39]]) 
lr
# Out:
# array([2], dtype=int64)

# %%
lr2 = classifier_regressor.predict([[10,49,0,3,3,55]]) 
lr2
# Out:
# array([2], dtype=int64)

# %%
lr3 = classifier_regressor.predict([[9,14,3,1,15,33]]) 
lr3
# Out:
# array([2], dtype=int64)

# %% [markdown]
# # Decision Tree

# %%
# importing the Decision Tree Classifer model
from sklearn.tree import DecisionTreeClassifier
treemodel = DecisionTreeClassifier(max_depth = 2)
print("TreeModel = ",treemodel)
#Fitting the x_train and y_train into the model
treemodel.fit(x_train, y_train)
# Out:
# TreeModel =  DecisionTreeClassifier(max_depth=2)
# DecisionTreeClassifier(max_depth=2)

# %%
#Plotting the chart for treemodel with max depth as 2
import  matplotlib.pyplot as plt
from sklearn import tree

plt.figure(figsize = (15,10))

tree.plot_tree(treemodel,filled = True)
# Out:
# [Text(0.5, 0.8333333333333334, 'x[5] <= 0.953\ngini = 0.596\nsamples = 1736\nvalue = [153, 1004, 383, 196]'),
#  Text(0.25, 0.5, 'x[5] <= -0.018\ngini = 0.417\nsamples = 1348\nvalue = [153, 999, 0, 196]'),
#  Text(0.125, 0.16666666666666666, 'gini = 0.282\nsamples = 900\nvalue = [153, 747, 0, 0]'),
#  Text(0.375, 0.16666666666666666, 'gini = 0.492\nsamples = 448\nvalue = [0, 252, 0, 196]'),
#  Text(0.75, 0.5, 'x[5] <= 1.907\ngini = 0.025\nsamples = 388\nvalue = [0, 5, 383, 0]'),
#  Text(0.625, 0.16666666666666666, 'gini = 0.0\nsamples = 365\nvalue = [0, 0, 365, 0]'),
#  Text(0.875, 0.16666666666666666, 'gini = 0.34\nsamples = 23\nvalue = [0, 5, 18, 0]')]

# %%
#Predicting the x_test and asssigning it to 
treemodel.predict(x_test)
y_pred = treemodel.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report
score = accuracy_score(y_pred,y_test)
print("Accuracy:",score)
# Out:
# Accuracy: 0.7599309153713298

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.71      0.83       936
#            2       1.00      0.99      1.00       222
#            3       0.00      0.00      0.00         0
#
#     accuracy                           0.76      1158
#    macro avg       0.50      0.42      0.46      1158
# weighted avg       1.00      0.76      0.86      1158
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
treemodel = DecisionTreeClassifier()
print("TreeModel = ",treemodel)
treemodel.fit(x_train, y_train)
# Out:
# TreeModel =  DecisionTreeClassifier()
# DecisionTreeClassifier()

# %%
import  matplotlib.pyplot as plt
from sklearn import tree
plt.figure(figsize = (15,10))
tree.plot_tree(treemodel,filled = True)
# Out:
# [Text(0.5769230769230769, 0.9166666666666666, 'x[5] <= 0.953\ngini = 0.596\nsamples = 1736\nvalue = [153, 1004, 383, 196]'),
#  Text(0.38461538461538464, 0.75, 'x[5] <= -0.018\ngini = 0.417\nsamples = 1348\nvalue = [153, 999, 0, 196]'),
#  Text(0.23076923076923078, 0.5833333333333334, 'x[4] <= -0.293\ngini = 0.282\nsamples = 900\nvalue = [153, 747, 0, 0]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[3] <= -0.018\ngini = 0.426\nsamples = 221\nvalue = [153, 68, 0, 0]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 153\nvalue = [153, 0, 0, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 68\nvalue = [0, 68, 0, 0]'),
#  Text(0.3076923076923077, 0.4166666666666667, 'gini = 0.0\nsamples = 679\nvalue = [0, 679, 0, 0]'),
#  Text(0.5384615384615384, 0.5833333333333334, 'x[4] <= 0.465\ngini = 0.492\nsamples = 448\nvalue = [0, 252, 0, 196]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'x[3] <= 0.663\ngini = 0.361\nsamples = 330\nvalue = [0, 252, 0, 78]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 250\nvalue = [0, 250, 0, 0]'),
#  Text(0.5384615384615384, 0.25, 'x[5] <= 0.936\ngini = 0.049\nsamples = 80\nvalue = [0, 2, 0, 78]'),
#  Text(0.46153846153846156, 0.08333333333333333, 'gini = 0.0\nsamples = 78\nvalue = [0, 0, 0, 78]'),
#  Text(0.6153846153846154, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.6153846153846154, 0.4166666666666667, 'gini = 0.0\nsamples = 118\nvalue = [0, 0, 0, 118]'),
#  Text(0.7692307692307693, 0.75, 'x[5] <= 1.907\ngini = 0.025\nsamples = 388\nvalue = [0, 5, 383, 0]'),
#  Text(0.6923076923076923, 0.5833333333333334, 'gini = 0.0\nsamples = 365\nvalue = [0, 0, 365, 0]'),
#  Text(0.8461538461538461, 0.5833333333333334, 'x[5] <= 1.924\ngini = 0.34\nsamples = 23\nvalue = [0, 5, 18, 0]'),
#  Text(0.7692307692307693, 0.4166666666666667, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0]'),
#  Text(0.9230769230769231, 0.4166666666666667, 'gini = 0.0\nsamples = 18\nvalue = [0, 0, 18, 0]')]

# %%
treemodel.predict(x_test)
# Out:
# array([1, 1, 1, ..., 2, 2, 1], dtype=int64)

# %%
y_pred = treemodel.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, ..., 2, 2, 1], dtype=int64)

# %%
score_dt = accuracy_score(y_pred,y_test)
print("Accuracy:",score_dt*100,"%")
# Out:
# Accuracy: 100.0 %

# %%
dt = treemodel.predict([[10,31,0,4,4,39]]) 
dt
# Out:
# array([2], dtype=int64)

# %%
dt2 = treemodel.predict([[10,49,0,3,3,55]]) 
dt2
# Out:
# array([2], dtype=int64)

# %%
dt3 = treemodel.predict([[9,14,3,1,15,33]]) 
dt3
# Out:
# array([2], dtype=int64)

# %% [markdown]
# # Random Forest

# %%
from sklearn.metrics import roc_curve,auc
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
import time
fit_rf = RandomForestClassifier(random_state = 40)

# %%
np.random.seed(40)
start=time.time()
param_dist={'max_depth':[2,3,4,5],
           'bootstrap':[True,False],
           'max_features':['auto','sqrt','log2',None],
           'criterion':['gini','entropy']}
cv_rf=GridSearchCV(fit_rf,cv=10,param_grid=param_dist,n_jobs=3)

cv_rf.fit(x_train,y_train)
print('best parameters using Grid Search: \n',cv_rf.best_params_)
end=time.time()
print('time taken in grid search: %0.2f'%(end-start) )
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 160 fits failed out of a total of 640.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 101 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 59 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [       nan 0.79608332 0.79608332 0.79608332        nan 0.86000598
#  0.86000598 0.91418178        nan 0.96255398 0.96255398 0.99826922
#         nan 0.98329679 0.98329679 0.99885057        nan 0.79608332
#  0.79608332 0.79608332        nan 0.89861803 0.89861803 0.91590924
#         nan 0.97753638 0.97753638 0.99884393        nan 0.99538901
#  0.99538901 1.                nan 0.79608332 0.79608332 0.79608332
#         nan 0.86750382 0.86750382 0.91590924        nan 0.97292206
#  0.97292206 0.99884393        nan 0.98848581 0.98848581 1.
#         nan 0.79608332 0.79608332 0.79608332        nan 0.89515647
#  0.89515647 0.91590924        nan 0.98040662 0.98040662 0.99884393
#         nan 0.9948143  0.9948143  1.        ]
#   warnings.warn(
# best parameters using Grid Search:
#  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': None}
# time taken in grid search: 177.14

# %%
fit_rf.set_params(criterion='entropy',max_features='log2',max_depth=5)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=5, max_features='log2',
#                        random_state=40)

# %%
fit_rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=5, max_features='log2',
#                        random_state=40)

# %%
prediction_rf=fit_rf.predict(x_test)
print(prediction_rf)
# Out:
# [1 1 1 ... 2 2 1]

# %%
score_rf=fit_rf.score(x_test,y_test)
print("Accuracy:",score_rf*100,"%")
# Out:
# Accuracy: 99.74093264248705 %

# %%
rf = fit_rf.predict([[10,31,0,4,4,39]]) 
rf
# Out:
# array([2], dtype=int64)

# %%
rf2 = fit_rf.predict([[10,49,0,3,3,55]]) 
rf2
# Out:
# array([2], dtype=int64)

# %%
rf3 = fit_rf.predict([[9,14,3,1,15,33]]) 
rf3
# Out:
# array([2], dtype=int64)

# %% [markdown]
# # K - Nearest Neighbour

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(x_train, y_train)
y_prediction = knn.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_prediction)
# Out:
# array([[126,  25,   0,   0],
#        [ 13, 633,   9,   7],
#        [  0,   8, 203,   9],
#        [  0,  22,  12,  91]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
score_knn = accuracy_score(y_true=y_test,y_pred = y_prediction,normalize = True)
print("Accuracy:",score_knn*100,"%")
# Out:
# Accuracy: 90.93264248704664 %

# %%
knnp = knn.predict([[10,31,0,4,4,39]]) 
knnp
# Out:
# array([1], dtype=int64)

# %%
knnp2 = knn.predict([[10,49,0,3,3,55]]) 
knnp2
# Out:
# array([2], dtype=int64)

# %%
knnp3 = knn.predict([[9,14,3,1,15,33]]) 
knnp3
# Out:
# array([2], dtype=int64)

# %% [markdown]
# # Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()

# %%
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
pred = model.predict(x_test)
print(pred[:150])
# Out:
# [1 1 1 1 1 3 3 1 1 3 1 3 1 3 2 1 1 2 1 1 2 1 2 2 2 0 3 2 2 2 3 2 1 1 1 1 2
#  1 0 2 2 3 0 1 3 2 1 3 3 1 1 2 1 3 2 1 3 1 1 1 3 0 1 1 1 2 1 1 1 2 3 1 3 0
#  1 1 1 1 0 1 1 2 0 1 1 1 2 0 1 1 3 1 1 1 1 0 1 1 1 3 1 1 0 2 2 2 2 3 3 3 1
#  1 1 3 1 3 1 1 2 3 2 1 2 1 1 2 0 1 1 3 1 3 2 1 3 1 1 2 0 0 3 2 0 1 2 1 1 1
#  0 1]

# %%
mat = confusion_matrix(pred,y_test)
names = np.unique(pred)
sns.heatmap(mat,square=True,annot=True,fmt='d',cbar = False)
plt.xlabel('Truth')
plt.ylabel('Predicted')
plt.plot()
# Out:
# []

# %%
score_gnb = accuracy_score(pred,y_test)
print("Accuracy:",score_gnb*100,"%")
# Out:
# Accuracy: 80.48359240069085 %

# %%
gnb = model.predict([[10,31,0,4,4,39]]) 
gnb
# Out:
# array([1], dtype=int64)

# %%
gnb2 = model.predict([[10,49,0,3,3,55]]) 
gnb2
# Out:
# array([1], dtype=int64)

# %%
gnb3 = model.predict([[9,14,3,1,15,33]]) 
gnb3
# Out:
# array([1], dtype=int64)

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
clf = SVC(kernel='linear')
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)

# %%
score_svm = accuracy_score(y_test,y_pred)
print("Accuracy:",score_svm*100,"%")
# Out:
# Accuracy: 88.86010362694302 %

# %%
svm = clf.predict([[10,31,0,4,4,39]]) 
svm
# Out:
# array([2], dtype=int64)

# %%
s2 = model.predict([[10,49,0,3,3,55]]) 
gnb2
# Out:
# array([1], dtype=int64)

# %% [markdown]
# # Data Comparison

# %%
data = {
    'Model_Name': ['Logistic Regression', 'Decision Tree', 'Random Forest', 'KNN','GuassianNB','SVM'],
    'Accuracy': [score_lr,score_dt,score_rf,score_knn,score_gnb,score_svm]
}
print("Comparison Table for all the Categorials Approaches")
comparison = pd.DataFrame(data)
comparison
# Out:
# Comparison Table for all the Categorials Approaches
#             Model_Name  Accuracy
# 0  Logistic Regression  0.886874
# 1        Decision Tree  1.000000
# 2        Random Forest  0.997409
# 3                  KNN  0.909326
# 4           GuassianNB  0.804836
# 5                  SVM  0.888601

# %%
comparison.sort_values(by='Accuracy', ascending=False)
# Out:
#             Model_Name  Accuracy
# 1        Decision Tree  1.000000
# 2        Random Forest  0.997409
# 3                  KNN  0.909326
# 5                  SVM  0.888601
# 0  Logistic Regression  0.886874
# 4           GuassianNB  0.804836

# %% [markdown]
# # Prediction Table

# %%
comparison.sort_values(by='Accuracy', ascending=False)
# Out:
#             Model_Name  Accuracy
# 1        Decision Tree  1.000000
# 2        Random Forest  0.997409
# 3                  KNN  0.909326
# 5                  SVM  0.888601
# 0  Logistic Regression  0.886874
# 4           GuassianNB  0.804836

# %%
data = pd.DataFrame({
    'Model_Name': ['Logistic Regression', 'Decision Tree', 'Random Forest', 'KNN', 'GaussianNB', 'SVM'],
    'Accuracy': [score_lr*100, score_dt*100, score_rf*100, score_knn*100, score_gnb*100, score_svm*100]
})

# Set the figure size
plt.figure(figsize=(8, 8))

# Create the bar plot
ax = sns.barplot(x='Model_Name', y='Accuracy', data=data)

# Add labels to each bar
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center',
                xytext=(0, 9), 
                textcoords='offset points')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')
plt.title('Accuracy vs Algorithms Bar chart')

# Display the plot
plt.show()
